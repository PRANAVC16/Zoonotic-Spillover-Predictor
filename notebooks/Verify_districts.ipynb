# %%
import pandas as pd

districts = pd.read_csv("C:/Users/chowd/Zoonotic-Spillover-Predictor/data/raw/outbreaks/district_master.csv")

print(districts)

print("\nNumber of districts:", len(districts))
# Out:
#          State        District  Latitude  Longitude               Forest_Type  \
# 0    Karnataka      Shivamogga   13.9299    75.5681  Tropical Moist Deciduous
# 1    Karnataka  Uttara Kannada   14.7937    74.6869        Tropical Evergreen
# 2    Karnataka  Chikkamagaluru   13.3161    75.7720        Tropical Evergreen
# 3    Karnataka          Kodagu   12.4244    75.7382        Tropical Evergreen
# 4       Kerala         Wayanad   11.6854    76.1320        Tropical Evergreen
# 5       Kerala          Kannur   11.8745    75.3704  Tropical Moist Deciduous
# 6          Goa       North Goa   15.4909    73.8278           Moist Deciduous
# 7          Goa       South Goa   15.1170    74.1240           Moist Deciduous
# 8  Maharashtra      Sindhudurg   16.3492    73.5594           Moist Deciduous
#
#   Elevation_Category
# 0             Medium
# 1             Medium
# 2               High
# 3               High
# 4               High
# 5                Low
# 6                Low
# ...
