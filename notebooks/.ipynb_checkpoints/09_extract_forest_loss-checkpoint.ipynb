# %%
import ee
import pandas as pd

ee.Initialize(project='ee-chowdharypranav2005')

districts = pd.read_csv(
    "../data/raw/outbreaks/district_master.csv"
)

print("Loaded", len(districts), "districts")
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import ee
#       2 import pandas as pd
#       3
# ----> 4 ee.Initialize(project='ee-chowdharypranav2005')
#       5
#       6 districts = pd.read_csv(
#       7     "../data/raw/outbreaks/district_master.csv"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ee\_utils.py:39, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      37     if new_key not in kwargs:
#      38       kwargs[new_key] = old_key_val
# ---> 39 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ee\__init__.py:230, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     213 """Initialize the EE library.
#     214
#     215 If this hasn't been called by the time any object constructor is used,
# ...

# %%
forest = ee.Image("UMD/hansen/global_forest_change_2023_v1_11")

# %%
def extract_forest_loss(lat, lon, buffer_radius=50000):

    region = ee.Geometry.Point([lon, lat]).buffer(buffer_radius)

    loss = forest.select("loss")

    stats = loss.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=region,
        scale=30,
        maxPixels=1e9
    )

    return stats.get("loss").getInfo()

# %%
value = extract_forest_loss(
    lat=13.9299,
    lon=75.5681
)

print(value)
# Out:
# 0.019143822343316123

# %%
records = []

for _, district in districts.iterrows():

    value = extract_forest_loss(
        district["Latitude"],
        district["Longitude"]
    )

    records.append({
        "State": district["State"],
        "District": district["District"],
        "Forest_Loss": value
    })

forest_df = pd.DataFrame(records)

forest_df.head()
# Out:
#        State        District  Forest_Loss
# 0  Karnataka      Shivamogga     0.019144
# 1  Karnataka  Uttara Kannada     0.008988
# 2  Karnataka  Chikkamagaluru     0.018034
# 3  Karnataka          Kodagu     0.021077
# 4     Kerala         Wayanad     0.016563

# %%
forest_df.to_csv(
    "../data/processed/forest_loss_western_ghats.csv",
    index=False
)

print("Forest Loss Dataset Saved!")
# Out:
# Forest Loss Dataset Saved!
