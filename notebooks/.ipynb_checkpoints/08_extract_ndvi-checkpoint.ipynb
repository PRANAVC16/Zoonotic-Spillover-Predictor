# %%
import ee
import geemap
import pandas as pd
import numpy as np
from pathlib import Path

print("Libraries imported.")
# Out:
# Libraries imported.

# %%
PROJECT_ID = "ee-chowdharypranav2005"

try:
    ee.Initialize(project=PROJECT_ID)
    print("✅ Google Earth Engine already authenticated.")
except Exception:
    print("Earth Engine authentication required...")
    ee.Authenticate()
    ee.Initialize(project=PROJECT_ID)
    print("✅ Google Earth Engine authenticated.")

print(f"Project: {PROJECT_ID}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Google Earth Engine already authenticated.
# Project: ee-chowdharypranav2005

# %%
DISTRICT_PATH = Path(
    "../data/raw/outbreaks/district_master.csv"
)

districts = pd.read_csv(
    DISTRICT_PATH
)

print("District master loaded.")
print("Shape:", districts.shape)

display(districts)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# District master loaded.
# Shape: (9, 6)
#          State        District  Latitude  Longitude               Forest_Type  \
# 0    Karnataka      Shivamogga   13.9299    75.5681  Tropical Moist Deciduous
# ...

# %%
required_columns = [
    "State",
    "District",
    "Latitude",
    "Longitude"
]

missing_columns = [
    col
    for col in required_columns
    if col not in districts.columns
]

if missing_columns:
    raise ValueError(
        f"Missing required columns: {missing_columns}"
    )

print("✅ District master columns validated.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ District master columns validated.

# %%
S2 = ee.ImageCollection(
    "COPERNICUS/S2_HARMONIZED"
)

CS_PLUS = ee.ImageCollection(
    "GOOGLE/CLOUD_SCORE_PLUS/V1/S2_HARMONIZED"
)

QA_BAND = "cs_cdf"

CLEAR_THRESHOLD = 0.60

# radius
BUFFER_RADIUS_METERS = 50_000

# Regional reduction scale
REDUCTION_SCALE = 30

print("Satellite configuration ready.")
print("Cloud threshold:", CLEAR_THRESHOLD)
print("Buffer radius:", BUFFER_RADIUS_METERS / 1000, "km")
print("Reduction scale:", REDUCTION_SCALE, "m")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Satellite configuration ready.
# Cloud threshold: 0.6
# Buffer radius: 50.0 km
# Reduction scale: 30 m

# %%
def build_annual_ndvi_collection(
    lat,
    lon,
    year,
    buffer_radius=BUFFER_RADIUS_METERS
):
    """
    Build a cloud-masked Sentinel-2 collection
    for one district-year.
    """

    lat = float(lat)
    lon = float(lon)
    year = int(year)

    point = ee.Geometry.Point(
        [lon, lat]
    )

    region = point.buffer(
        buffer_radius
    )

    start_date = ee.Date.fromYMD(
        year,
        1,
        1
    )

    end_date = ee.Date.fromYMD(
        year + 1,
        1,
        1
    )

    collection = (
        S2
        .filterBounds(region)
        .filterDate(
            start_date,
            end_date
        )
        .linkCollection(
            CS_PLUS,
            [QA_BAND]
        )
        .map(
            lambda image:
            image.updateMask(
                image
                .select(QA_BAND)
                .gte(CLEAR_THRESHOLD)
            )
        )
        .select(
            ["B4", "B8"]
        )
    )

    return collection, region
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def extract_ndvi(
    lat,
    lon,
    year,
    buffer_radius=BUFFER_RADIUS_METERS,
    scale=REDUCTION_SCALE
):
    """
    Extract annual mean NDVI for one district-year.

    Returns
    -------
    dict
        NDVI
        Image_Count
    """

    collection, region = build_annual_ndvi_collection(
        lat=lat,
        lon=lon,
        year=year,
        buffer_radius=buffer_radius
    )

    image_count = int(
        collection
        .size()
        .getInfo()
    )

    if image_count == 0:

        return {
            "NDVI": np.nan,
            "Image_Count": 0
        }

    composite = (
        collection
        .median()
    )

    ndvi_image = (
        composite
        .normalizedDifference(
            ["B8", "B4"]
        )
        .rename("NDVI")
    )

    result = (
        ndvi_image
        .reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=region,
            scale=scale,
            bestEffort=True,
            maxPixels=1e9,
            tileScale=4
        )
        .get("NDVI")
        .getInfo()
    )

    if result is None:

        ndvi_value = np.nan

    else:

        ndvi_value = float(result)

    return {
        "NDVI": ndvi_value,
        "Image_Count": image_count
    }
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ndvi_mean
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ndvi_mean
#
# ...

# %%
test_locations = [
    {
        "Name": "Shivamogga 2018",
        "Latitude": 13.9299,
        "Longitude": 75.5681,
        "Year": 2018
    },

    {
        "Name": "Wayanad 2021",
        "Latitude": 11.6854,
        "Longitude": 76.1320,
        "Year": 2021
    },

    {
        "Name": "North Goa 2024",
        "Latitude": 15.4909,
        "Longitude": 73.8278,
        "Year": 2024
    }
]


test_results = []

for test in test_locations:

    print(
        f"Processing {test['Name']}..."
    )

    result = extract_ndvi(
        lat=test["Latitude"],
        lon=test["Longitude"],
        year=test["Year"]
    )

    test_results.append(
        {
            "Location": test["Name"],
            "NDVI": result["NDVI"],
            "Image_Count": result["Image_Count"]
        }
    )


test_df = pd.DataFrame(
    test_results
)

display(test_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing Shivamogga 2018...
# Processing Wayanad 2021...
# Processing North Goa 2024...
#           Location      NDVI  Image_Count
# 0  Shivamogga 2018  0.394578          209
# 1     Wayanad 2021  0.515912          439
# ...

# %%
print("Test observations:", len(test_df))

print(
    "Unique NDVI values:",
    test_df["NDVI"].nunique()
)

print(
    "Missing NDVI values:",
    test_df["NDVI"].isna().sum()
)

display(
    test_df.round(4)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Test observations: 3
# Unique NDVI values: 3
# Missing NDVI values: 0
#           Location    NDVI  Image_Count
# 0  Shivamogga 2018  0.3946          209
# 1     Wayanad 2021  0.5159          439
# ...

# %%
VISUAL_YEAR = 2021
VISUAL_DISTRICT = "Wayanad"

visual_row = districts[
    districts["District"] == VISUAL_DISTRICT
].iloc[0]

visual_lat = visual_row["Latitude"]
visual_lon = visual_row["Longitude"]

visual_collection, visual_region = (
    build_annual_ndvi_collection(
        lat=visual_lat,
        lon=visual_lon,
        year=VISUAL_YEAR
    )
)

visual_composite = (
    visual_collection
    .median()
)

visual_ndvi = (
    visual_composite
    .normalizedDifference(
        ["B8", "B4"]
    )
    .rename("NDVI")
)

Map = geemap.Map(
    center=[
        visual_lat,
        visual_lon
    ],
    zoom=8
)

ndvi_vis = {
    "min": 0.0,
    "max": 0.8,
    "palette": [
        "white",
        "yellow",
        "lightgreen",
        "green",
        "darkgreen"
    ]
}

Map.addLayer(
    visual_ndvi,
    ndvi_vis,
    f"{VISUAL_DISTRICT} NDVI {VISUAL_YEAR}"
)

Map.addLayer(
    visual_region,
    {},
    "50 km Study Region"
)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[np.float64(11.6854), np.float64(76.132)], controls=(WidgetControl(options=['position', 'transparen…

# %%
START_YEAR = 2015
END_YEAR = 2024

records = []

total_jobs = (
    len(districts)
    *
    (END_YEAR - START_YEAR + 1)
)

job_number = 0


for _, district in districts.iterrows():

    state = district["State"]
    district_name = district["District"]

    lat = float(
        district["Latitude"]
    )

    lon = float(
        district["Longitude"]
    )

    for year in range(
        START_YEAR,
        END_YEAR + 1
    ):

        job_number += 1

        print(
            f"[{job_number}/{total_jobs}] "
            f"{district_name} - {year}"
        )

        try:

            result = extract_ndvi(
                lat=lat,
                lon=lon,
                year=year
            )

            ndvi_value = result["NDVI"]
            image_count = result["Image_Count"]

        except Exception as error:

            print(
                f"⚠️ Error for "
                f"{district_name} {year}: "
                f"{error}"
            )

            ndvi_value = np.nan
            image_count = 0

        records.append(
            {
                "State": state,
                "District": district_name,
                "Year": year,
                "NDVI": ndvi_value,
                "Image_Count": image_count
            }
        )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [1/90] Shivamogga - 2015
# [2/90] Shivamogga - 2016
# [3/90] Shivamogga - 2017
# [4/90] Shivamogga - 2018
# [5/90] Shivamogga - 2019
# [6/90] Shivamogga - 2020
# [7/90] Shivamogga - 2021
# [8/90] Shivamogga - 2022
# ...

# %%
ndvi_audit_df = pd.DataFrame(
    records
)

print(
    "Shape:",
    ndvi_audit_df.shape
)

display(
    ndvi_audit_df.head(15)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Shape: (90, 5)
#         State        District  Year      NDVI  Image_Count
# 0   Karnataka      Shivamogga  2015  0.501104           27
# 1   Karnataka      Shivamogga  2016  0.392206          187
# ...

# %%
print("=" * 70)
print("NDVI DATA QUALITY AUDIT")
print("=" * 70)

print(
    "\nRows:",
    len(ndvi_audit_df)
)

print(
    "\nMissing NDVI:",
    ndvi_audit_df["NDVI"]
    .isna()
    .sum()
)

print(
    "\nUnique NDVI values:",
    ndvi_audit_df["NDVI"]
    .nunique()
)

print(
    "\nNDVI descriptive statistics:"
)

display(
    ndvi_audit_df["NDVI"]
    .describe()
    .to_frame()
)

print(
    "\nImage-count statistics:"
)

display(
    ndvi_audit_df["Image_Count"]
    .describe()
    .to_frame()
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...
# NDVI DATA QUALITY AUDIT
# ...
#
# Rows: 90
#
# Missing NDVI: 0
#
# Unique NDVI values: 90
#
# NDVI descriptive statistics:
#             NDVI
# count  90.000000
# mean    0.366698
# std     0.153726
# min     0.142723
# ...

# %%
district_summary = (
    ndvi_audit_df
    .groupby("District")
    .agg(
        NDVI_Min=("NDVI", "min"),
        NDVI_Mean=("NDVI", "mean"),
        NDVI_Max=("NDVI", "max"),
        NDVI_Std=("NDVI", "std"),
        Mean_Image_Count=("Image_Count", "mean")
    )
    .round(4)
)

display(
    district_summary
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 NDVI_Min  NDVI_Mean  NDVI_Max  NDVI_Std  Mean_Image_Count
# District
# Chikkamagaluru    0.4321     0.4697    0.5711    0.0394             244.1
# ...

# %%
year_summary = (
    ndvi_audit_df
    .groupby("Year")
    .agg(
        NDVI_Min=("NDVI", "min"),
        NDVI_Mean=("NDVI", "mean"),
        NDVI_Max=("NDVI", "max"),
        NDVI_Std=("NDVI", "std"),
        Mean_Image_Count=("Image_Count", "mean")
    )
    .round(4)
)

display(
    year_summary
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       NDVI_Min  NDVI_Mean  NDVI_Max  NDVI_Std  Mean_Image_Count
# Year
# 2015    0.1661     0.4222    0.6255    0.1884           34.2222
# 2016    0.1505     0.3542    0.5228    0.1483          232.8889
# ...

# %%
ndvi_2015 = (
    ndvi_audit_df[
        ndvi_audit_df["Year"] == 2015
    ]
    [
        [
            "State",
            "District",
            "NDVI",
            "Image_Count"
        ]
    ]
)

display(
    ndvi_2015.round(4)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           State        District    NDVI  Image_Count
# 0     Karnataka      Shivamogga  0.5011           27
# 10    Karnataka  Uttara Kannada  0.5476           45
# 20    Karnataka  Chikkamagaluru  0.5711           36
# ...

# %%
duplicate_counts = (
    ndvi_audit_df["NDVI"]
    .round(8)
    .value_counts()
)

print(
    "Most frequently repeated NDVI values:"
)

display(
    duplicate_counts.head(10)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Most frequently repeated NDVI values:
# NDVI
# 0.501104    1
# 0.392206    1
# 0.428025    1
# 0.394578    1
# 0.391763    1
# 0.423659    1
# 0.432609    1
# 0.439875    1
# 0.445630    1
# 0.421058    1
# ...

# %%
invalid_ndvi = ndvi_audit_df[
    (ndvi_audit_df["NDVI"] < -1)
    |
    (ndvi_audit_df["NDVI"] > 1)
]

print(
    "Values outside valid NDVI range:",
    len(invalid_ndvi)
)

if len(invalid_ndvi) > 0:
    display(invalid_ndvi)
else:
    print("All NDVI values are within [-1, 1].")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Values outside valid NDVI range: 0
# All NDVI values are within [-1, 1].

# %%
no_imagery = ndvi_audit_df[
    ndvi_audit_df["Image_Count"] == 0
]

print(
    "District-years with zero usable images:",
    len(no_imagery)
)

if len(no_imagery) > 0:

    display(
        no_imagery
    )

else:

    print(
        "Every district-year has usable imagery."
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# District-years with zero usable images: 0
# Every district-year has usable imagery.

# %%
ndvi_dataset = (
    ndvi_audit_df[
        [
            "State",
            "District",
            "Year",
            "NDVI"
        ]
    ]
    .copy()
)

display(
    ndvi_dataset.head()
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        State    District  Year      NDVI
# 0  Karnataka  Shivamogga  2015  0.501104
# 1  Karnataka  Shivamogga  2016  0.392206
# 2  Karnataka  Shivamogga  2017  0.428025
# 3  Karnataka  Shivamogga  2018  0.394578
# ...

# %%
OUTPUT_PATH = Path(
    "../data/processed/"
    "ndvi_western_ghats_2015_2024.csv"
)

ndvi_dataset.to_csv(
    OUTPUT_PATH,
    index=False
)

print(
    "Corrected NDVI dataset saved:"
)

print(
    OUTPUT_PATH
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Corrected NDVI dataset saved:
# ..\data\processed\ndvi_western_ghats_2015_2024.csv

# %%
AUDIT_PATH = Path(
    "../data/processed/"
    "ndvi_western_ghats_2015_2024_audit.csv"
)

ndvi_audit_df.to_csv(
    AUDIT_PATH,
    index=False
)

print(
    "NDVI audit dataset saved:"
)

print(
    AUDIT_PATH
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NDVI audit dataset saved:
# ..\data\processed\ndvi_western_ghats_2015_2024_audit.csv

# %%
print("=" * 72)
print("CORRECTED NDVI EXTRACTION COMPLETE")
print("=" * 72)

print(
    "\nDataset shape:",
    ndvi_dataset.shape
)

print(
    "Districts:",
    ndvi_dataset["District"].nunique()
)

print(
    "Years:",
    ndvi_dataset["Year"].min(),
    "-",
    ndvi_dataset["Year"].max()
)

print(
    "Unique NDVI values:",
    ndvi_dataset["NDVI"].nunique()
)

print(
    "Missing NDVI:",
    ndvi_dataset["NDVI"]
    .isna()
    .sum()
)

print(
    "\nNDVI range:"
)

print(
    "Minimum:",
    round(
        ndvi_dataset["NDVI"].min(),
        4
    )
)

print(
    "Maximum:",
    round(
        ndvi_dataset["NDVI"].max(),
        4
    )
)

print(
    "Mean:",
    round(
        ndvi_dataset["NDVI"].mean(),
        4
    )
)

print(
    "\nNotebook 08 complete."
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...
# CORRECTED NDVI EXTRACTION COMPLETE
# ...
#
# Dataset shape: (90, 4)
# Districts: 9
# Years: 2015 - 2024
# Unique NDVI values: 90
# Missing NDVI: 0
#
# NDVI range:
# Minimum: 0.1427
# Maximum: 0.6255
# Mean: 0.3667
#
# ...
