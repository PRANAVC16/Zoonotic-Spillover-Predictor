# %%
import ee
import geemap

ee.Authenticate()

ee.Initialize()

print("Google Earth Engine Connected!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
# ...

# %%
import pandas as pd

ee.Initialize(project='ee-chowdharypranav2005')

print("✅ Earth Engine Connected")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 ee.Initialize(project='ee-chowdharypranav2005')
#       4
#       5 print("✅ Earth Engine Connected")
#
# NameError: name 'ee' is not defined

# %%
districts = pd.read_csv(
    "../data/raw/outbreaks/district_master.csv"
)

districts.head()
# Out:
#        State        District  Latitude  Longitude               Forest_Type  \
# 0  Karnataka      Shivamogga   13.9299    75.5681  Tropical Moist Deciduous
# 1  Karnataka  Uttara Kannada   14.7937    74.6869        Tropical Evergreen
# 2  Karnataka  Chikkamagaluru   13.3161    75.7720        Tropical Evergreen
# 3  Karnataka          Kodagu   12.4244    75.7382        Tropical Evergreen
# 4     Kerala         Wayanad   11.6854    76.1320        Tropical Evergreen
#
#   Elevation_Category
# 0             Medium
# 1             Medium
# 2               High
# 3               High
# 4               High

# %%
district = districts.iloc[0]

lat = district["Latitude"]
lon = district["Longitude"]

year = 2015

point = ee.Geometry.Point([lon, lat])
region = point.buffer(50000)  # 50 km buffer
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sentinel = (
    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
    .filterBounds(region)
    .filterDate(f"{year}-01-01", f"{year}-12-31")
    .median()
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ndvi = sentinel.normalizedDifference(
    ["B8", "B4"]
).rename("NDVI")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ndvi_mean = ndvi.reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=region,
    scale=30,
    maxPixels=1e9
)

print(ndvi_mean.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'NDVI': 0.5868659691704521}

# %%
Map = geemap.Map(center=[lat, lon], zoom=9)

ndvi_vis = {
    "min": 0,
    "max": 1,
    "palette": ["white", "yellow", "green"]
}

Map.addLayer(ndvi, ndvi_vis, f"NDVI {year}")

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[np.float64(13.9299), np.float64(75.5681)], controls=(WidgetControl(options=['position', 'transpare…

# %%
def extract_ndvi(lat, lon, year, buffer_radius=...):
   
    point = ee.Geometry.Point([lon, lat])
    
    collection = (
        ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") # or "COPERNICUS/S2_SR"
        .filterDate(f"{year}-01-01", f"{year}-12-31")
        .filterBounds(point)
        .select(["B4", "B8"]) 
    )
    
    return ndvi_mean.get("NDVI").getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
value = extract_ndvi(
    lat=13.9299,
    lon=75.5681,
    year=2015
)

print(value)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.5868659691704522

# %%
years = range(2015, 2025)

records = []

for _, district in districts.iterrows():

    for year in range(2015, 2025):

        print(f"Processing {district['District']} - {year}")

        ndvi = extract_ndvi(
            district["Latitude"],
            district["Longitude"],
            year
        )

        records.append({
            "State": district["State"],
            "District": district["District"],
            "Year": year,
            "NDVI": ndvi
        })

ndvi_dataset = pd.DataFrame(records)

ndvi_dataset.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing Shivamogga - 2015
# Processing Shivamogga - 2016
# Processing Shivamogga - 2017
# Processing Shivamogga - 2018
# Processing Shivamogga - 2019
# Processing Shivamogga - 2020
# Processing Shivamogga - 2021
# ...

# %%
ndvi_dataset.to_csv(
    "../data/processed/ndvi_western_ghats_2015_2024.csv",
    index=False
)

print("NDVI Dataset Saved!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ndvi_dataset.to_csv(
#       2     "../data/processed/ndvi_western_ghats_2015_2024.csv",
#       3     index=False
#       4 )
#
# NameError: name 'ndvi_dataset' is not defined

# %%
print(ndvi_dataset.shape)

print(ndvi_dataset.isnull().sum())

print(ndvi_dataset.describe())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (90, 4)
# State       0
# District    0
# Year        0
# NDVI        0
# dtype: int64
#               Year          NDVI
# count    90.000000  9.000000e+01
# mean   2019.500000  5.868660e-01
# std       2.888373  1.116443e-16
# ...
